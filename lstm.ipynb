# %% [markdown]
# <a href="https://colab.research.google.com/github/minhvn1433/Deep-learning-project/blob/main/lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### **Set Up**

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from gensim.utils import simple_preprocess
from transformers import get_linear_schedule_with_warmup

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import torch
from torch import nn
from torch.optim import AdamW
from torch.utils.data import Dataset, DataLoader

# %%
def seed_everything(seed_value):
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = True


seed_everything(86)

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"There are {torch.cuda.device_count()} GPU(s) available.")
    print("Device name:", torch.cuda.get_device_name(0))
else:
    print("No GPU available, using the CPU instead.")
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# Device name: Tesla T4

# %% [markdown]
# ###### **Load Data**

# %%
train_df = pd.read_excel("train.xlsx")
valid_df = pd.read_excel("valid.xlsx")
test_df = pd.read_excel("test.xlsx")

train_df = pd.concat([train_df, valid_df], ignore_index=True)
skf = StratifiedKFold(n_splits=5)
for fold, (train_index, valid_index) in enumerate(
    skf.split(X=train_df, y=train_df.Emotion)
):
    train_df.loc[valid_index, "kfold"] = fold

train_df.sample(5)
# Out:
#         Emotion                                           Sentence  kfold
# 3706  Enjoyment  dễ thương ghê ! làm mình nhớ các cậu bạn cùng ...    2.0
# 3913  Enjoyment                               đáng yêuc vãi anh ơi    3.0
# 234    Surprise                                  bất ngờ chưa =)))    0.0
# 658    Surprise              cha con y chang nhau 😂 1 khuôn đúc ra    0.0
# 821   Enjoyment              lợi ích của việc giữ vững quan điểm 😄    0.0

# %% [markdown]
# ###### **DataLoader**

# %%
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(train_df.Sentence)

# %%
class SentimentDataset(Dataset):
    def __init__(self, df, tokenizer, max_length):
        self.df = df
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        row = self.df.iloc[index]
        sentence, label = self.get_input_data(row)

        sequence = self.tokenizer.texts_to_sequences([sentence])
        padded = pad_sequences(
            sequence, maxlen=self.max_length, padding="post", truncating="post"
        )

        return {
            "sentence": sentence,
            "inputs": torch.tensor(padded).flatten(),
            "targets": torch.tensor(label),
        }

    def labelencoder(self, label):
        if label == "Enjoyment":
            return 0
        elif label == "Disgust":
            return 1
        elif label == "Sadness":
            return 2
        elif label == "Anger":
            return 3
        elif label == "Surprise":
            return 4
        elif label == "Fear":
            return 5
        else:
            return 6

    def get_input_data(self, row):
        sentence = row["Sentence"]
        sentence = " ".join(simple_preprocess(sentence))
        label = self.labelencoder(row["Emotion"])

        return sentence, label

# %%
def prepare_loaders(df, fold, tokenizer):
    df_train = df[df.kfold != fold].reset_index(drop=True)
    df_valid = df[df.kfold == fold].reset_index(drop=True)

    train_dataset = SentimentDataset(df_train, tokenizer, max_length=120)
    valid_dataset = SentimentDataset(df_valid, tokenizer, max_length=120)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
    valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=True, num_workers=2)

    return train_loader, valid_loader

# %% [markdown]
# ###### **Train & Eval Function**

# %%
def train(model, criterion, optimizer, scheduler, loader):
    model.train()
    size = len(loader.dataset)
    num_batches = len(loader)
    train_loss, correct = 0, 0

    for data in loader:
        inputs = data["inputs"].to(device)
        targets = data["targets"].to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()

        train_loss += loss.item()
        correct += (outputs.argmax(1) == targets).sum().item()

    train_loss /= num_batches
    correct /= size
    print(f"loss: {train_loss:.4f}   accuracy: {correct:.4f}   ", end="")

# %%
def eval(model, criterion, loader):
    model.eval()
    size = len(loader.dataset)
    num_batches = len(loader)
    val_loss, correct = 0, 0

    with torch.no_grad():
        for data in loader:
            inputs = data["inputs"].to(device)
            targets = data["targets"].to(device)

            outputs = model(inputs)
            loss = criterion(outputs, targets)

            val_loss += loss.item()
            correct += (outputs.argmax(1) == targets).sum().item()

    val_loss /= num_batches
    correct /= size
    print(f"val_loss: {val_loss:.4f}   val_accuracy: {correct:.4f}")

    return correct

# %% [markdown]
# ###### **Model**

# %%
class SentimentClassifier(nn.Module):
    def __init__(
        self, vocab_size, embedding_dim, max_length, lstm_dim, dense_dim, num_classes
    ):
        super(SentimentClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, lstm_dim, bidirectional=True)
        self.fc1 = nn.Linear(lstm_dim * 2, dense_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(dense_dim, num_classes)

    def forward(self, x):
        x = self.embedding(x)
        output, (x, _) = self.lstm(x.permute(1, 0, 2))
        x = torch.cat((x[-2, :, :], x[-1, :, :]), dim=1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ###### **Training**

# %%
num_epochs = 30
best_accs = []

for fold in range(skf.n_splits):
    print(f"Fold {fold + 1}")
    train_loader, valid_loader = prepare_loaders(train_df, fold, tokenizer)

    model = SentimentClassifier(
        vocab_size=5000,
        embedding_dim=64,
        max_length=120,
        lstm_dim=45,
        dense_dim=30,
        num_classes=7,
    ).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = AdamW(model.parameters(), lr=9.3e-4)
    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=0, num_training_steps=len(train_loader) * num_epochs
    )

    best_acc = 0
    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}   ", end="")

        train(model, criterion, optimizer, scheduler, train_loader)
        val_acc = eval(model, criterion, valid_loader)

        if val_acc > best_acc:
            torch.save(model.state_dict(), f"lstm_fold_{fold + 1}.pth")
            best_acc = val_acc
    best_accs.append(best_acc)

avg_acc = torch.tensor(best_accs).mean().item()
print(f"Average accuracy: {avg_acc:.4f}")
# Out:
# Fold 1
# Epoch 1/30   loss: 1.7908   accuracy: 0.2757   val_loss: 1.7564   val_accuracy: 0.2839
# Epoch 2/30   loss: 1.7284   accuracy: 0.2879   val_loss: 1.6883   val_accuracy: 0.3176
# Epoch 3/30   loss: 1.5862   accuracy: 0.3662   val_loss: 1.5762   val_accuracy: 0.3769
# Epoch 4/30   loss: 1.4051   accuracy: 0.4612   val_loss: 1.5254   val_accuracy: 0.4090
# Epoch 5/30   loss: 1.2577   accuracy: 0.5294   val_loss: 1.5125   val_accuracy: 0.4306
# Epoch 6/30   loss: 1.1373   accuracy: 0.5797   val_loss: 1.5217   val_accuracy: 0.4467
# Epoch 7/30   loss: 1.0354   accuracy: 0.6244   val_loss: 1.5259   val_accuracy: 0.4475
# Epoch 8/30   loss: 0.9457   accuracy: 0.6587   val_loss: 1.5899   val_accuracy: 0.4539
# Epoch 9/30   loss: 0.8606   accuracy: 0.7002   val_loss: 1.5858   val_accuracy: 0.4619
# Epoch 10/30   loss: 0.7796   accuracy: 0.7225   val_loss: 1.6388   val_accuracy: 0.4579
# Epoch 11/30   loss: 0.7026   accuracy: 0.7538   val_loss: 1.7266   val_accuracy: 0.4611
# Epoch 12/30   loss: 0.6325   accuracy: 0.7852   val_loss: 1.8119   val_accuracy: 0.4555
# Epoch 13/30   loss: 0.5766   accuracy: 0.8097   val_loss: 1.8265   val_accuracy: 0.4547
# Epoch 14/30   loss: 0.5164   accuracy: 0.8328   val_loss: 1.9277   val_accuracy: 0.4707
# Epoch 15/30   loss: 0.4640   accuracy: 0.8544   val_loss: 2.0267   val_accuracy: 0.4739
# Epoch 16/30   loss: 0.4196   accuracy: 0.8713   val_loss: 2.1405   val_accuracy: 0.4563
# Epoch 17/30   loss: 0.3750   accuracy: 0.8887   val_loss: 2.2198   val_accuracy: 0.4603
# Epoch 18/30   loss: 0.3387   accuracy: 0.9042   val_loss: 2.3756   val_accuracy: 0.4603
# Epoch 19/30   loss: 0.3050   accuracy: 0.9166   val_loss: 2.3986   val_accuracy: 0.4459
# Epoch 20/30   loss: 0.2725   accuracy: 0.9264   val_loss: 2.5296   val_accuracy: 0.4595
# Epoch 21/30   loss: 0.2470   accuracy: 0.9334   val_loss: 2.6138   val_accuracy: 0.4555
# Epoch 22/30   loss: 0.2227   accuracy: 0.9437   val_loss: 2.6994   val_accuracy: 0.4531
# Epoch 23/30   loss: 0.2030   accuracy: 0.9513   val_loss: 2.7671   val_accuracy: 0.4515
# Epoch 24/30   loss: 0.1861   accuracy: 0.9551   val_loss: 2.8583   val_accuracy: 0.4459
# Epoch 25/30   loss: 0.1716   accuracy: 0.9595   val_loss: 2.8994   val_accuracy: 0.4531
# Epoch 26/30   loss: 0.1599   accuracy: 0.9653   val_loss: 2.9839   val_accuracy: 0.4499
# Epoch 27/30   loss: 0.1495   accuracy: 0.9683   val_loss: 3.0094   val_accuracy: 0.4539
# Epoch 28/30   loss: 0.1414   accuracy: 0.9715   val_loss: 3.0610   val_accuracy: 0.4515
# Epoch 29/30   loss: 0.1350   accuracy: 0.9719   val_loss: 3.0767   val_accuracy: 0.4547
# Epoch 30/30   loss: 0.1312   accuracy: 0.9731   val_loss: 3.0965   val_accuracy: 0.4531
# Fold 2
# Epoch 1/30   loss: 1.7771   accuracy: 0.2841   val_loss: 1.7454   val_accuracy: 0.2999
# Epoch 2/30   loss: 1.6805   accuracy: 0.3439   val_loss: 1.6734   val_accuracy: 0.3496
# Epoch 3/30   loss: 1.5395   accuracy: 0.4000   val_loss: 1.6119   val_accuracy: 0.3681
# Epoch 4/30   loss: 1.3827   accuracy: 0.4730   val_loss: 1.5939   val_accuracy: 0.4010
# Epoch 5/30   loss: 1.2395   accuracy: 0.5422   val_loss: 1.5880   val_accuracy: 0.4010
# Epoch 6/30   loss: 1.1172   accuracy: 0.5885   val_loss: 1.6587   val_accuracy: 0.4146
# Epoch 7/30   loss: 1.0102   accuracy: 0.6280   val_loss: 1.6911   val_accuracy: 0.4258
# Epoch 8/30   loss: 0.9147   accuracy: 0.6651   val_loss: 1.7035   val_accuracy: 0.4290
# Epoch 9/30   loss: 0.8296   accuracy: 0.7006   val_loss: 1.7337   val_accuracy: 0.4274
# Epoch 10/30   loss: 0.7489   accuracy: 0.7331   val_loss: 1.8396   val_accuracy: 0.4395
# Epoch 11/30   loss: 0.6802   accuracy: 0.7638   val_loss: 1.9324   val_accuracy: 0.4346
# Epoch 12/30   loss: 0.6136   accuracy: 0.7937   val_loss: 1.9978   val_accuracy: 0.4338
# Epoch 13/30   loss: 0.5578   accuracy: 0.8155   val_loss: 2.0695   val_accuracy: 0.4435
# Epoch 14/30   loss: 0.5013   accuracy: 0.8370   val_loss: 2.1607   val_accuracy: 0.4403
# Epoch 15/30   loss: 0.4569   accuracy: 0.8576   val_loss: 2.2613   val_accuracy: 0.4403
# Epoch 16/30   loss: 0.4133   accuracy: 0.8759   val_loss: 2.4099   val_accuracy: 0.4427
# Epoch 17/30   loss: 0.3684   accuracy: 0.8893   val_loss: 2.5020   val_accuracy: 0.4362
# Epoch 18/30   loss: 0.3357   accuracy: 0.9035   val_loss: 2.5510   val_accuracy: 0.4322
# Epoch 19/30   loss: 0.3019   accuracy: 0.9154   val_loss: 2.6386   val_accuracy: 0.4419
# Epoch 20/30   loss: 0.2710   accuracy: 0.9276   val_loss: 2.8174   val_accuracy: 0.4354
# Epoch 21/30   loss: 0.2478   accuracy: 0.9322   val_loss: 2.8792   val_accuracy: 0.4322
# Epoch 22/30   loss: 0.2247   accuracy: 0.9441   val_loss: 2.9890   val_accuracy: 0.4379
# Epoch 23/30   loss: 0.2020   accuracy: 0.9497   val_loss: 3.0912   val_accuracy: 0.4362
# Epoch 24/30   loss: 0.1856   accuracy: 0.9555   val_loss: 3.1632   val_accuracy: 0.4411
# Epoch 25/30   loss: 0.1703   accuracy: 0.9585   val_loss: 3.2592   val_accuracy: 0.4419
# Epoch 26/30   loss: 0.1572   accuracy: 0.9623   val_loss: 3.2929   val_accuracy: 0.4387
# Epoch 27/30   loss: 0.1461   accuracy: 0.9643   val_loss: 3.4150   val_accuracy: 0.4411
# Epoch 28/30   loss: 0.1380   accuracy: 0.9665   val_loss: 3.4466   val_accuracy: 0.4403
# Epoch 29/30   loss: 0.1322   accuracy: 0.9687   val_loss: 3.4765   val_accuracy: 0.4403
# Epoch 30/30   loss: 0.1280   accuracy: 0.9697   val_loss: 3.4817   val_accuracy: 0.4411
# Fold 3
# Epoch 1/30   loss: 1.7877   accuracy: 0.2843   val_loss: 1.7577   val_accuracy: 0.2839
# Epoch 2/30   loss: 1.6996   accuracy: 0.3060   val_loss: 1.6681   val_accuracy: 0.3328
# Epoch 3/30   loss: 1.5531   accuracy: 0.3842   val_loss: 1.5875   val_accuracy: 0.3721
# Epoch 4/30   loss: 1.4050   accuracy: 0.4536   val_loss: 1.5382   val_accuracy: 0.4026
# Epoch 5/30   loss: 1.2759   accuracy: 0.5063   val_loss: 1.5173   val_accuracy: 0.4242
# Epoch 6/30   loss: 1.1581   accuracy: 0.5574   val_loss: 1.5533   val_accuracy: 0.4403
# Epoch 7/30   loss: 1.0556   accuracy: 0.6064   val_loss: 1.5536   val_accuracy: 0.4419
# Epoch 8/30   loss: 0.9638   accuracy: 0.6541   val_loss: 1.5707   val_accuracy: 0.4330
# Epoch 9/30   loss: 0.8785   accuracy: 0.6874   val_loss: 1.6363   val_accuracy: 0.4539
# Epoch 10/30   loss: 0.7970   accuracy: 0.7207   val_loss: 1.6666   val_accuracy: 0.4443
# Epoch 11/30   loss: 0.7285   accuracy: 0.7499   val_loss: 1.7297   val_accuracy: 0.4507
# Epoch 12/30   loss: 0.6614   accuracy: 0.7806   val_loss: 1.8537   val_accuracy: 0.4403
# Epoch 13/30   loss: 0.6001   accuracy: 0.8031   val_loss: 1.9100   val_accuracy: 0.4411
# Epoch 14/30   loss: 0.5471   accuracy: 0.8247   val_loss: 1.9993   val_accuracy: 0.4411
# Epoch 15/30   loss: 0.4922   accuracy: 0.8482   val_loss: 2.0834   val_accuracy: 0.4346
# Epoch 16/30   loss: 0.4459   accuracy: 0.8632   val_loss: 2.2047   val_accuracy: 0.4395
# Epoch 17/30   loss: 0.4045   accuracy: 0.8775   val_loss: 2.2222   val_accuracy: 0.4322
# Epoch 18/30   loss: 0.3621   accuracy: 0.8967   val_loss: 2.3942   val_accuracy: 0.4338
# Epoch 19/30   loss: 0.3285   accuracy: 0.9064   val_loss: 2.4808   val_accuracy: 0.4379
# Epoch 20/30   loss: 0.2945   accuracy: 0.9192   val_loss: 2.6729   val_accuracy: 0.4403
# Epoch 21/30   loss: 0.2643   accuracy: 0.9288   val_loss: 2.7224   val_accuracy: 0.4443
# Epoch 22/30   loss: 0.2394   accuracy: 0.9390   val_loss: 2.7914   val_accuracy: 0.4395
# Epoch 23/30   loss: 0.2183   accuracy: 0.9469   val_loss: 2.8979   val_accuracy: 0.4314
# Epoch 24/30   loss: 0.1979   accuracy: 0.9527   val_loss: 2.9676   val_accuracy: 0.4330
# Epoch 25/30   loss: 0.1833   accuracy: 0.9585   val_loss: 3.1250   val_accuracy: 0.4322
# Epoch 26/30   loss: 0.1688   accuracy: 0.9617   val_loss: 3.1289   val_accuracy: 0.4282
# Epoch 27/30   loss: 0.1571   accuracy: 0.9685   val_loss: 3.1873   val_accuracy: 0.4266
# Epoch 28/30   loss: 0.1486   accuracy: 0.9695   val_loss: 3.2385   val_accuracy: 0.4290
# Epoch 29/30   loss: 0.1415   accuracy: 0.9703   val_loss: 3.2570   val_accuracy: 0.4298
# Epoch 30/30   loss: 0.1373   accuracy: 0.9721   val_loss: 3.2839   val_accuracy: 0.4306
# Fold 4
# Epoch 1/30   loss: 1.7829   accuracy: 0.2779   val_loss: 1.7474   val_accuracy: 0.2831
# Epoch 2/30   loss: 1.6842   accuracy: 0.3363   val_loss: 1.6701   val_accuracy: 0.3328
# Epoch 3/30   loss: 1.5271   accuracy: 0.4177   val_loss: 1.5926   val_accuracy: 0.3729
# Epoch 4/30   loss: 1.3703   accuracy: 0.4851   val_loss: 1.5525   val_accuracy: 0.4202
# Epoch 5/30   loss: 1.2327   accuracy: 0.5456   val_loss: 1.5312   val_accuracy: 0.4274
# Epoch 6/30   loss: 1.1120   accuracy: 0.5953   val_loss: 1.5477   val_accuracy: 0.4419
# Epoch 7/30   loss: 1.0040   accuracy: 0.6399   val_loss: 1.6008   val_accuracy: 0.4387
# Epoch 8/30   loss: 0.9077   accuracy: 0.6768   val_loss: 1.6401   val_accuracy: 0.4427
# Epoch 9/30   loss: 0.8196   accuracy: 0.7147   val_loss: 1.6427   val_accuracy: 0.4579
# Epoch 10/30   loss: 0.7359   accuracy: 0.7437   val_loss: 1.6904   val_accuracy: 0.4563
# Epoch 11/30   loss: 0.6635   accuracy: 0.7692   val_loss: 1.7747   val_accuracy: 0.4587
# Epoch 12/30   loss: 0.5959   accuracy: 0.7987   val_loss: 1.8525   val_accuracy: 0.4627
# Epoch 13/30   loss: 0.5324   accuracy: 0.8249   val_loss: 1.9799   val_accuracy: 0.4595
# Epoch 14/30   loss: 0.4759   accuracy: 0.8466   val_loss: 2.0301   val_accuracy: 0.4523
# Epoch 15/30   loss: 0.4203   accuracy: 0.8695   val_loss: 2.1352   val_accuracy: 0.4491
# Epoch 16/30   loss: 0.3718   accuracy: 0.8875   val_loss: 2.2313   val_accuracy: 0.4435
# Epoch 17/30   loss: 0.3315   accuracy: 0.9060   val_loss: 2.3042   val_accuracy: 0.4523
# Epoch 18/30   loss: 0.2930   accuracy: 0.9186   val_loss: 2.4620   val_accuracy: 0.4507
# Epoch 19/30   loss: 0.2585   accuracy: 0.9296   val_loss: 2.5314   val_accuracy: 0.4467
# Epoch 20/30   loss: 0.2280   accuracy: 0.9382   val_loss: 2.6598   val_accuracy: 0.4531
# Epoch 21/30   loss: 0.2029   accuracy: 0.9467   val_loss: 2.7282   val_accuracy: 0.4555
# Epoch 22/30   loss: 0.1793   accuracy: 0.9569   val_loss: 2.8103   val_accuracy: 0.4411
# Epoch 23/30   loss: 0.1609   accuracy: 0.9621   val_loss: 2.9727   val_accuracy: 0.4507
# Epoch 24/30   loss: 0.1425   accuracy: 0.9675   val_loss: 3.0316   val_accuracy: 0.4427
# Epoch 25/30   loss: 0.1289   accuracy: 0.9719   val_loss: 3.1244   val_accuracy: 0.4370
# Epoch 26/30   loss: 0.1171   accuracy: 0.9751   val_loss: 3.1899   val_accuracy: 0.4370
# Epoch 27/30   loss: 0.1086   accuracy: 0.9783   val_loss: 3.2734   val_accuracy: 0.4395
# Epoch 28/30   loss: 0.1007   accuracy: 0.9797   val_loss: 3.3065   val_accuracy: 0.4387
# Epoch 29/30   loss: 0.0951   accuracy: 0.9803   val_loss: 3.3452   val_accuracy: 0.4403
# Epoch 30/30   loss: 0.0915   accuracy: 0.9818   val_loss: 3.3445   val_accuracy: 0.4379
# Fold 5
# Epoch 1/30   loss: 1.7735   accuracy: 0.2797   val_loss: 1.7443   val_accuracy: 0.3114
# Epoch 2/30   loss: 1.6777   accuracy: 0.3442   val_loss: 1.6709   val_accuracy: 0.3443
# Epoch 3/30   loss: 1.5454   accuracy: 0.3982   val_loss: 1.5999   val_accuracy: 0.3732
# Epoch 4/30   loss: 1.4017   accuracy: 0.4711   val_loss: 1.5901   val_accuracy: 0.3997
# Epoch 5/30   loss: 1.2632   accuracy: 0.5355   val_loss: 1.5480   val_accuracy: 0.4238
# Epoch 6/30   loss: 1.1451   accuracy: 0.5824   val_loss: 1.5545   val_accuracy: 0.4374
# Epoch 7/30   loss: 1.0412   accuracy: 0.6245   val_loss: 1.5559   val_accuracy: 0.4478
# Epoch 8/30   loss: 0.9443   accuracy: 0.6632   val_loss: 1.6029   val_accuracy: 0.4510
# Epoch 9/30   loss: 0.8581   accuracy: 0.6991   val_loss: 1.6684   val_accuracy: 0.4543
# Epoch 10/30   loss: 0.7783   accuracy: 0.7308   val_loss: 1.7085   val_accuracy: 0.4543
# Epoch 11/30   loss: 0.7040   accuracy: 0.7556   val_loss: 1.7927   val_accuracy: 0.4494
# Epoch 12/30   loss: 0.6347   accuracy: 0.7849   val_loss: 1.9283   val_accuracy: 0.4599
# Epoch 13/30   loss: 0.5746   accuracy: 0.8109   val_loss: 1.9287   val_accuracy: 0.4438
# Epoch 14/30   loss: 0.5234   accuracy: 0.8304   val_loss: 2.0023   val_accuracy: 0.4518
# Epoch 15/30   loss: 0.4656   accuracy: 0.8530   val_loss: 2.0956   val_accuracy: 0.4591
# Epoch 16/30   loss: 0.4200   accuracy: 0.8703   val_loss: 2.2128   val_accuracy: 0.4599
# Epoch 17/30   loss: 0.3745   accuracy: 0.8867   val_loss: 2.3769   val_accuracy: 0.4591
# Epoch 18/30   loss: 0.3360   accuracy: 0.9014   val_loss: 2.3958   val_accuracy: 0.4567
# Epoch 19/30   loss: 0.3021   accuracy: 0.9120   val_loss: 2.5489   val_accuracy: 0.4575
# Epoch 20/30   loss: 0.2709   accuracy: 0.9242   val_loss: 2.6004   val_accuracy: 0.4567
# Epoch 21/30   loss: 0.2444   accuracy: 0.9352   val_loss: 2.7494   val_accuracy: 0.4559
# Epoch 22/30   loss: 0.2201   accuracy: 0.9439   val_loss: 2.8671   val_accuracy: 0.4567
# Epoch 23/30   loss: 0.1995   accuracy: 0.9513   val_loss: 2.9492   val_accuracy: 0.4510
# Epoch 24/30   loss: 0.1796   accuracy: 0.9555   val_loss: 2.9967   val_accuracy: 0.4526
# Epoch 25/30   loss: 0.1651   accuracy: 0.9609   val_loss: 3.0874   val_accuracy: 0.4502
# Epoch 26/30   loss: 0.1515   accuracy: 0.9655   val_loss: 3.1546   val_accuracy: 0.4486
# Epoch 27/30   loss: 0.1429   accuracy: 0.9679   val_loss: 3.2083   val_accuracy: 0.4502
# Epoch 28/30   loss: 0.1327   accuracy: 0.9699   val_loss: 3.2395   val_accuracy: 0.4535
# Epoch 29/30   loss: 0.1268   accuracy: 0.9719   val_loss: 3.2784   val_accuracy: 0.4526
# Epoch 30/30   loss: 0.1223   accuracy: 0.9747   val_loss: 3.2845   val_accuracy: 0.4535
# Average accuracy: 0.4588

# %% [markdown]
# ###### **Testing**

# %%
models = []


def test(loader):
    for fold in range(skf.n_splits):
        model = SentimentClassifier(
            vocab_size=5000,
            embedding_dim=64,
            max_length=120,
            lstm_dim=45,
            dense_dim=30,
            num_classes=7,
        ).to(device)
        model.load_state_dict(torch.load(f"lstm_fold_{fold + 1}.pth"))
        model.eval()
        models.append(model)

    predicts = []
    true_labels = []

    with torch.no_grad():
        for data in loader:
            inputs = data["inputs"].to(device)
            targets = data["targets"].to(device)

            total_outs = []
            for model in models:
                outputs = model(inputs)
                total_outs.append(outputs)

            total_outs = torch.stack(total_outs)
            _, pred = torch.max(total_outs.mean(0), 1)
            predicts.extend(pred)
            true_labels.extend(targets)

    predicts = torch.stack(predicts).cpu()
    true_labels = torch.stack(true_labels).cpu()
    print(classification_report(true_labels, predicts, digits=4))

# %%
test_dataset = SentimentDataset(test_df, tokenizer, max_length=120)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=2)
test(test_loader)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.5821    0.6062    0.5939       193
#            1     0.4762    0.6061    0.5333       132
#            2     0.6484    0.5086    0.5700       116
#            3     0.5000    0.1500    0.2308        40
#            4     0.5000    0.1622    0.2449        37
#            5     0.7419    0.5000    0.5974        46
#            6     0.4213    0.5814    0.4886       129
#
#     accuracy                         0.5281       693
#    macro avg     0.5528    0.4449    0.4656       693
# weighted avg     0.5446    0.5281    0.5194       693

# %% [markdown]
# ###### **Inference**

# %%
emotions = ["Enjoyment", "Disgust", "Sadness", "Anger", "Surprise", "Fear", "Other"]


def infer(sentence, max_length=120):
    sentence = " ".join(simple_preprocess(sentence))

    sequence = tokenizer.texts_to_sequences([sentence])
    padded = pad_sequences(
        sequence, maxlen=max_length, padding="post", truncating="post"
    )

    inputs = torch.tensor(padded).to(device)

    total_outs = []
    for model in models:
        outputs = model(inputs)
        total_outs.append(outputs)

    total_outs = torch.stack(total_outs)
    _, pred = torch.max(total_outs.mean(0), 1)

    print(emotions[pred])

# %%
infer("Uồi lại được học bổng thích thế!")
infer("Mấy điều ông ấy nói làm tao ghê tởm.")
infer("Mình lại tạch môn rồi buồn ghê :(")
infer("Đừng có mà động vào người tao. Tao đang hơi bực.")
infer("Không thể tin được, sao có thể được 5 điểm tất cả các môn.")
infer("Lúc thầy ấy giận cả lớp trông thật đáng sợ.")
# Out:
# Enjoyment
# Disgust
# Sadness
# Disgust
# Other
# Fear

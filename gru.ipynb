# %% [markdown]
# <a href="https://colab.research.google.com/github/minhvn1433/Deep-learning-project/blob/main/gru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### **Set Up**

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from gensim.utils import simple_preprocess
from transformers import get_linear_schedule_with_warmup

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import torch
from torch import nn
from torch.optim import AdamW
from torch.utils.data import Dataset, DataLoader

# %%
def seed_everything(seed_value):
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = True


seed_everything(86)

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"There are {torch.cuda.device_count()} GPU(s) available.")
    print("Device name:", torch.cuda.get_device_name(0))
else:
    print("No GPU available, using the CPU instead.")
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# Device name: Tesla T4

# %% [markdown]
# ###### **Load Data**

# %%
train_df = pd.read_excel("train.xlsx")
valid_df = pd.read_excel("valid.xlsx")
test_df = pd.read_excel("test.xlsx")

train_df = pd.concat([train_df, valid_df], ignore_index=True)
skf = StratifiedKFold(n_splits=5)
for fold, (train_index, valid_index) in enumerate(
    skf.split(X=train_df, y=train_df.Emotion)
):
    train_df.loc[valid_index, "kfold"] = fold

train_df.sample(5)
# Out:
#         Emotion                                           Sentence  kfold
# 3706  Enjoyment  dễ thương ghê ! làm mình nhớ các cậu bạn cùng ...    2.0
# 3913  Enjoyment                               đáng yêuc vãi anh ơi    3.0
# 234    Surprise                                  bất ngờ chưa =)))    0.0
# 658    Surprise              cha con y chang nhau 😂 1 khuôn đúc ra    0.0
# 821   Enjoyment              lợi ích của việc giữ vững quan điểm 😄    0.0

# %% [markdown]
# ###### **DataLoader**

# %%
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(train_df.Sentence)

# %%
class SentimentDataset(Dataset):
    def __init__(self, df, tokenizer, max_length):
        self.df = df
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        row = self.df.iloc[index]
        sentence, label = self.get_input_data(row)

        sequence = self.tokenizer.texts_to_sequences([sentence])
        padded = pad_sequences(
            sequence, maxlen=self.max_length, padding="post", truncating="post"
        )

        return {
            "sentence": sentence,
            "inputs": torch.tensor(padded).flatten(),
            "targets": torch.tensor(label),
        }

    def labelencoder(self, label):
        if label == "Enjoyment":
            return 0
        elif label == "Disgust":
            return 1
        elif label == "Sadness":
            return 2
        elif label == "Anger":
            return 3
        elif label == "Surprise":
            return 4
        elif label == "Fear":
            return 5
        else:
            return 6

    def get_input_data(self, row):
        sentence = row["Sentence"]
        sentence = " ".join(simple_preprocess(sentence))
        label = self.labelencoder(row["Emotion"])

        return sentence, label

# %%
def prepare_loaders(df, fold, tokenizer):
    df_train = df[df.kfold != fold].reset_index(drop=True)
    df_valid = df[df.kfold == fold].reset_index(drop=True)

    train_dataset = SentimentDataset(df_train, tokenizer, max_length=120)
    valid_dataset = SentimentDataset(df_valid, tokenizer, max_length=120)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
    valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=True, num_workers=2)

    return train_loader, valid_loader

# %% [markdown]
# ###### **Train & Eval Function**

# %%
def train(model, criterion, optimizer, scheduler, loader):
    model.train()
    size = len(loader.dataset)
    num_batches = len(loader)
    train_loss, correct = 0, 0

    for data in loader:
        inputs = data["inputs"].to(device)
        targets = data["targets"].to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()

        train_loss += loss.item()
        correct += (outputs.argmax(1) == targets).sum().item()

    train_loss /= num_batches
    correct /= size
    print(f"loss: {train_loss:.4f}   accuracy: {correct:.4f}   ", end="")

# %%
def eval(model, criterion, loader):
    model.eval()
    size = len(loader.dataset)
    num_batches = len(loader)
    val_loss, correct = 0, 0

    with torch.no_grad():
        for data in loader:
            inputs = data["inputs"].to(device)
            targets = data["targets"].to(device)

            outputs = model(inputs)
            loss = criterion(outputs, targets)

            val_loss += loss.item()
            correct += (outputs.argmax(1) == targets).sum().item()

    val_loss /= num_batches
    correct /= size
    print(f"val_loss: {val_loss:.4f}   val_accuracy: {correct:.4f}")

    return correct

# %% [markdown]
# ###### **Model**

# %%
class SentimentClassifier(nn.Module):
    def __init__(
        self, vocab_size, embedding_dim, max_length, gru_dim, dense_dim, num_classes
    ):
        super(SentimentClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.gru = nn.GRU(embedding_dim, gru_dim, bidirectional=True)
        self.fc1 = nn.Linear(gru_dim * 2, dense_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(dense_dim, num_classes)

    def forward(self, x):
        x = self.embedding(x)
        _, x = self.gru(x.permute(1, 0, 2))
        x = torch.cat((x[-2, :, :], x[-1, :, :]), dim=1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ###### **Training**

# %%
num_epochs = 30
best_accs = []

for fold in range(skf.n_splits):
    print(f"Fold {fold + 1}")
    train_loader, valid_loader = prepare_loaders(train_df, fold, tokenizer)

    model = SentimentClassifier(
        vocab_size=5000,
        embedding_dim=64,
        max_length=120,
        gru_dim=45,
        dense_dim=30,
        num_classes=7,
    ).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = AdamW(model.parameters(), lr=9.3e-4)
    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=0, num_training_steps=len(train_loader) * num_epochs
    )

    best_acc = 0
    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}   ", end="")

        train(model, criterion, optimizer, scheduler, train_loader)
        val_acc = eval(model, criterion, valid_loader)

        if val_acc > best_acc:
            torch.save(model.state_dict(), f"gru_fold_{fold + 1}.pth")
            best_acc = val_acc
    best_accs.append(best_acc)

avg_acc = torch.tensor(best_accs).mean().item()
print(f"Average accuracy: {avg_acc:.4f}")
# Out:
# Fold 1
# Epoch 1/30   loss: 1.7746   accuracy: 0.2807   val_loss: 1.7479   val_accuracy: 0.2831
# Epoch 2/30   loss: 1.6822   accuracy: 0.3295   val_loss: 1.6570   val_accuracy: 0.3472
# Epoch 3/30   loss: 1.5298   accuracy: 0.4057   val_loss: 1.5817   val_accuracy: 0.3865
# Epoch 4/30   loss: 1.3863   accuracy: 0.4692   val_loss: 1.5418   val_accuracy: 0.4090
# Epoch 5/30   loss: 1.2681   accuracy: 0.5266   val_loss: 1.5615   val_accuracy: 0.4194
# Epoch 6/30   loss: 1.1597   accuracy: 0.5677   val_loss: 1.6063   val_accuracy: 0.4210
# Epoch 7/30   loss: 1.0675   accuracy: 0.6132   val_loss: 1.6127   val_accuracy: 0.4362
# Epoch 8/30   loss: 0.9732   accuracy: 0.6537   val_loss: 1.6406   val_accuracy: 0.4483
# Epoch 9/30   loss: 0.8970   accuracy: 0.6828   val_loss: 1.6992   val_accuracy: 0.4523
# Epoch 10/30   loss: 0.8182   accuracy: 0.7187   val_loss: 1.7512   val_accuracy: 0.4539
# Epoch 11/30   loss: 0.7449   accuracy: 0.7417   val_loss: 1.8136   val_accuracy: 0.4507
# Epoch 12/30   loss: 0.6772   accuracy: 0.7734   val_loss: 1.9072   val_accuracy: 0.4619
# Epoch 13/30   loss: 0.6170   accuracy: 0.7981   val_loss: 2.0211   val_accuracy: 0.4627
# Epoch 14/30   loss: 0.5578   accuracy: 0.8205   val_loss: 2.0913   val_accuracy: 0.4539
# Epoch 15/30   loss: 0.5042   accuracy: 0.8438   val_loss: 2.1946   val_accuracy: 0.4531
# Epoch 16/30   loss: 0.4588   accuracy: 0.8600   val_loss: 2.3555   val_accuracy: 0.4531
# Epoch 17/30   loss: 0.4149   accuracy: 0.8777   val_loss: 2.4587   val_accuracy: 0.4443
# Epoch 18/30   loss: 0.3740   accuracy: 0.8909   val_loss: 2.5104   val_accuracy: 0.4362
# Epoch 19/30   loss: 0.3378   accuracy: 0.9040   val_loss: 2.6098   val_accuracy: 0.4346
# Epoch 20/30   loss: 0.3035   accuracy: 0.9176   val_loss: 2.7636   val_accuracy: 0.4314
# Epoch 21/30   loss: 0.2780   accuracy: 0.9272   val_loss: 2.8381   val_accuracy: 0.4370
# Epoch 22/30   loss: 0.2522   accuracy: 0.9368   val_loss: 2.9438   val_accuracy: 0.4314
# Epoch 23/30   loss: 0.2298   accuracy: 0.9465   val_loss: 3.0511   val_accuracy: 0.4330
# Epoch 24/30   loss: 0.2109   accuracy: 0.9507   val_loss: 3.1130   val_accuracy: 0.4314
# Epoch 25/30   loss: 0.1955   accuracy: 0.9573   val_loss: 3.2307   val_accuracy: 0.4250
# Epoch 26/30   loss: 0.1810   accuracy: 0.9607   val_loss: 3.2805   val_accuracy: 0.4290
# Epoch 27/30   loss: 0.1694   accuracy: 0.9641   val_loss: 3.3470   val_accuracy: 0.4258
# Epoch 28/30   loss: 0.1609   accuracy: 0.9667   val_loss: 3.3789   val_accuracy: 0.4250
# Epoch 29/30   loss: 0.1542   accuracy: 0.9687   val_loss: 3.4305   val_accuracy: 0.4250
# Epoch 30/30   loss: 0.1497   accuracy: 0.9703   val_loss: 3.4258   val_accuracy: 0.4234
# Fold 2
# Epoch 1/30   loss: 1.7887   accuracy: 0.2775   val_loss: 1.7388   val_accuracy: 0.2999
# Epoch 2/30   loss: 1.6637   accuracy: 0.3359   val_loss: 1.6473   val_accuracy: 0.3480
# Epoch 3/30   loss: 1.5160   accuracy: 0.4004   val_loss: 1.5778   val_accuracy: 0.3769
# Epoch 4/30   loss: 1.3912   accuracy: 0.4664   val_loss: 1.5455   val_accuracy: 0.3970
# Epoch 5/30   loss: 1.2798   accuracy: 0.5226   val_loss: 1.5472   val_accuracy: 0.4162
# Epoch 6/30   loss: 1.1722   accuracy: 0.5669   val_loss: 1.5480   val_accuracy: 0.4194
# Epoch 7/30   loss: 1.0706   accuracy: 0.6170   val_loss: 1.5581   val_accuracy: 0.4387
# Epoch 8/30   loss: 0.9653   accuracy: 0.6521   val_loss: 1.6078   val_accuracy: 0.4419
# Epoch 9/30   loss: 0.8566   accuracy: 0.7018   val_loss: 1.6609   val_accuracy: 0.4499
# Epoch 10/30   loss: 0.7527   accuracy: 0.7431   val_loss: 1.7360   val_accuracy: 0.4451
# Epoch 11/30   loss: 0.6550   accuracy: 0.7762   val_loss: 1.8503   val_accuracy: 0.4555
# Epoch 12/30   loss: 0.5714   accuracy: 0.8133   val_loss: 1.9409   val_accuracy: 0.4491
# Epoch 13/30   loss: 0.4925   accuracy: 0.8416   val_loss: 2.0876   val_accuracy: 0.4515
# Epoch 14/30   loss: 0.4311   accuracy: 0.8671   val_loss: 2.1869   val_accuracy: 0.4387
# Epoch 15/30   loss: 0.3733   accuracy: 0.8873   val_loss: 2.3368   val_accuracy: 0.4411
# Epoch 16/30   loss: 0.3182   accuracy: 0.9044   val_loss: 2.4968   val_accuracy: 0.4379
# Epoch 17/30   loss: 0.2738   accuracy: 0.9256   val_loss: 2.6002   val_accuracy: 0.4379
# Epoch 18/30   loss: 0.2352   accuracy: 0.9380   val_loss: 2.7608   val_accuracy: 0.4435
# Epoch 19/30   loss: 0.2012   accuracy: 0.9481   val_loss: 2.9142   val_accuracy: 0.4387
# Epoch 20/30   loss: 0.1735   accuracy: 0.9597   val_loss: 3.0027   val_accuracy: 0.4322
# Epoch 21/30   loss: 0.1483   accuracy: 0.9685   val_loss: 3.1179   val_accuracy: 0.4306
# Epoch 22/30   loss: 0.1272   accuracy: 0.9739   val_loss: 3.2337   val_accuracy: 0.4322
# Epoch 23/30   loss: 0.1115   accuracy: 0.9765   val_loss: 3.3490   val_accuracy: 0.4314
# Epoch 24/30   loss: 0.0957   accuracy: 0.9799   val_loss: 3.3807   val_accuracy: 0.4314
# Epoch 25/30   loss: 0.0846   accuracy: 0.9836   val_loss: 3.5381   val_accuracy: 0.4298
# Epoch 26/30   loss: 0.0748   accuracy: 0.9850   val_loss: 3.5907   val_accuracy: 0.4290
# Epoch 27/30   loss: 0.0687   accuracy: 0.9874   val_loss: 3.6336   val_accuracy: 0.4218
# Epoch 28/30   loss: 0.0634   accuracy: 0.9890   val_loss: 3.6908   val_accuracy: 0.4290
# Epoch 29/30   loss: 0.0595   accuracy: 0.9900   val_loss: 3.7114   val_accuracy: 0.4298
# Epoch 30/30   loss: 0.0569   accuracy: 0.9906   val_loss: 3.7220   val_accuracy: 0.4274
# Fold 3
# Epoch 1/30   loss: 1.7709   accuracy: 0.2807   val_loss: 1.7408   val_accuracy: 0.2999
# Epoch 2/30   loss: 1.6899   accuracy: 0.3301   val_loss: 1.6784   val_accuracy: 0.3264
# Epoch 3/30   loss: 1.5500   accuracy: 0.4057   val_loss: 1.5846   val_accuracy: 0.3945
# Epoch 4/30   loss: 1.3882   accuracy: 0.4811   val_loss: 1.5567   val_accuracy: 0.3945
# Epoch 5/30   loss: 1.2490   accuracy: 0.5416   val_loss: 1.5735   val_accuracy: 0.4330
# Epoch 6/30   loss: 1.1345   accuracy: 0.5885   val_loss: 1.5396   val_accuracy: 0.4346
# Epoch 7/30   loss: 1.0329   accuracy: 0.6340   val_loss: 1.5613   val_accuracy: 0.4411
# Epoch 8/30   loss: 0.9361   accuracy: 0.6744   val_loss: 1.5968   val_accuracy: 0.4483
# Epoch 9/30   loss: 0.8464   accuracy: 0.7100   val_loss: 1.6372   val_accuracy: 0.4475
# Epoch 10/30   loss: 0.7595   accuracy: 0.7512   val_loss: 1.7318   val_accuracy: 0.4515
# Epoch 11/30   loss: 0.6814   accuracy: 0.7716   val_loss: 1.7870   val_accuracy: 0.4499
# Epoch 12/30   loss: 0.5980   accuracy: 0.8095   val_loss: 1.8564   val_accuracy: 0.4491
# Epoch 13/30   loss: 0.5237   accuracy: 0.8370   val_loss: 1.9803   val_accuracy: 0.4362
# Epoch 14/30   loss: 0.4424   accuracy: 0.8675   val_loss: 2.1913   val_accuracy: 0.4515
# Epoch 15/30   loss: 0.3754   accuracy: 0.8935   val_loss: 2.2466   val_accuracy: 0.4475
# Epoch 16/30   loss: 0.3128   accuracy: 0.9136   val_loss: 2.4206   val_accuracy: 0.4379
# Epoch 17/30   loss: 0.2604   accuracy: 0.9326   val_loss: 2.5041   val_accuracy: 0.4411
# Epoch 18/30   loss: 0.2151   accuracy: 0.9467   val_loss: 2.6263   val_accuracy: 0.4387
# Epoch 19/30   loss: 0.1760   accuracy: 0.9579   val_loss: 2.7741   val_accuracy: 0.4403
# Epoch 20/30   loss: 0.1461   accuracy: 0.9683   val_loss: 2.8959   val_accuracy: 0.4314
# Epoch 21/30   loss: 0.1197   accuracy: 0.9745   val_loss: 3.0874   val_accuracy: 0.4354
# Epoch 22/30   loss: 0.0986   accuracy: 0.9797   val_loss: 3.1783   val_accuracy: 0.4362
# Epoch 23/30   loss: 0.0812   accuracy: 0.9848   val_loss: 3.3013   val_accuracy: 0.4274
# Epoch 24/30   loss: 0.0676   accuracy: 0.9888   val_loss: 3.4070   val_accuracy: 0.4354
# Epoch 25/30   loss: 0.0572   accuracy: 0.9910   val_loss: 3.4568   val_accuracy: 0.4298
# Epoch 26/30   loss: 0.0488   accuracy: 0.9926   val_loss: 3.5677   val_accuracy: 0.4298
# Epoch 27/30   loss: 0.0429   accuracy: 0.9940   val_loss: 3.6177   val_accuracy: 0.4306
# Epoch 28/30   loss: 0.0386   accuracy: 0.9954   val_loss: 3.6560   val_accuracy: 0.4306
# Epoch 29/30   loss: 0.0358   accuracy: 0.9956   val_loss: 3.6905   val_accuracy: 0.4322
# Epoch 30/30   loss: 0.0340   accuracy: 0.9964   val_loss: 3.6963   val_accuracy: 0.4322
# Fold 4
# Epoch 1/30   loss: 1.7643   accuracy: 0.2863   val_loss: 1.7040   val_accuracy: 0.3304
# Epoch 2/30   loss: 1.6379   accuracy: 0.3525   val_loss: 1.5994   val_accuracy: 0.3657
# Epoch 3/30   loss: 1.4923   accuracy: 0.4179   val_loss: 1.5539   val_accuracy: 0.3913
# Epoch 4/30   loss: 1.3765   accuracy: 0.4762   val_loss: 1.5227   val_accuracy: 0.4194
# Epoch 5/30   loss: 1.2627   accuracy: 0.5304   val_loss: 1.5802   val_accuracy: 0.4379
# Epoch 6/30   loss: 1.1707   accuracy: 0.5637   val_loss: 1.5257   val_accuracy: 0.4451
# Epoch 7/30   loss: 1.0736   accuracy: 0.6058   val_loss: 1.5827   val_accuracy: 0.4499
# Epoch 8/30   loss: 0.9881   accuracy: 0.6427   val_loss: 1.5719   val_accuracy: 0.4539
# Epoch 9/30   loss: 0.9077   accuracy: 0.6786   val_loss: 1.6321   val_accuracy: 0.4667
# Epoch 10/30   loss: 0.8285   accuracy: 0.7102   val_loss: 1.7260   val_accuracy: 0.4707
# Epoch 11/30   loss: 0.7631   accuracy: 0.7365   val_loss: 1.8254   val_accuracy: 0.4619
# Epoch 12/30   loss: 0.6946   accuracy: 0.7586   val_loss: 1.8304   val_accuracy: 0.4667
# Epoch 13/30   loss: 0.6301   accuracy: 0.7852   val_loss: 1.8933   val_accuracy: 0.4627
# Epoch 14/30   loss: 0.5727   accuracy: 0.8093   val_loss: 1.9618   val_accuracy: 0.4611
# Epoch 15/30   loss: 0.5206   accuracy: 0.8306   val_loss: 2.0862   val_accuracy: 0.4611
# Epoch 16/30   loss: 0.4732   accuracy: 0.8484   val_loss: 2.0995   val_accuracy: 0.4627
# Epoch 17/30   loss: 0.4289   accuracy: 0.8695   val_loss: 2.2418   val_accuracy: 0.4563
# Epoch 18/30   loss: 0.3897   accuracy: 0.8825   val_loss: 2.3428   val_accuracy: 0.4619
# Epoch 19/30   loss: 0.3564   accuracy: 0.8965   val_loss: 2.3817   val_accuracy: 0.4611
# Epoch 20/30   loss: 0.3219   accuracy: 0.9126   val_loss: 2.5453   val_accuracy: 0.4683
# Epoch 21/30   loss: 0.2955   accuracy: 0.9200   val_loss: 2.6326   val_accuracy: 0.4603
# Epoch 22/30   loss: 0.2693   accuracy: 0.9320   val_loss: 2.7489   val_accuracy: 0.4627
# Epoch 23/30   loss: 0.2458   accuracy: 0.9414   val_loss: 2.7833   val_accuracy: 0.4579
# Epoch 24/30   loss: 0.2264   accuracy: 0.9469   val_loss: 2.8740   val_accuracy: 0.4587
# Epoch 25/30   loss: 0.2090   accuracy: 0.9537   val_loss: 2.9462   val_accuracy: 0.4571
# Epoch 26/30   loss: 0.1954   accuracy: 0.9577   val_loss: 2.9652   val_accuracy: 0.4579
# Epoch 27/30   loss: 0.1831   accuracy: 0.9619   val_loss: 3.0426   val_accuracy: 0.4603
# Epoch 28/30   loss: 0.1740   accuracy: 0.9655   val_loss: 3.0855   val_accuracy: 0.4587
# Epoch 29/30   loss: 0.1671   accuracy: 0.9667   val_loss: 3.1043   val_accuracy: 0.4563
# Epoch 30/30   loss: 0.1624   accuracy: 0.9689   val_loss: 3.1187   val_accuracy: 0.4587
# Fold 5
# Epoch 1/30   loss: 1.7780   accuracy: 0.2745   val_loss: 1.7511   val_accuracy: 0.2865
# Epoch 2/30   loss: 1.6690   accuracy: 0.3304   val_loss: 1.6511   val_accuracy: 0.3371
# Epoch 3/30   loss: 1.5106   accuracy: 0.4040   val_loss: 1.5964   val_accuracy: 0.3628
# Epoch 4/30   loss: 1.3812   accuracy: 0.4675   val_loss: 1.5696   val_accuracy: 0.3941
# Epoch 5/30   loss: 1.2683   accuracy: 0.5245   val_loss: 1.5632   val_accuracy: 0.4117
# Epoch 6/30   loss: 1.1536   accuracy: 0.5664   val_loss: 1.5911   val_accuracy: 0.3965
# Epoch 7/30   loss: 1.0456   accuracy: 0.6173   val_loss: 1.5784   val_accuracy: 0.4189
# Epoch 8/30   loss: 0.9365   accuracy: 0.6634   val_loss: 1.6145   val_accuracy: 0.4446
# Epoch 9/30   loss: 0.8273   accuracy: 0.7075   val_loss: 1.6688   val_accuracy: 0.4366
# Epoch 10/30   loss: 0.7294   accuracy: 0.7464   val_loss: 1.7515   val_accuracy: 0.4446
# Epoch 11/30   loss: 0.6316   accuracy: 0.7853   val_loss: 1.8574   val_accuracy: 0.4438
# Epoch 12/30   loss: 0.5419   accuracy: 0.8176   val_loss: 1.9804   val_accuracy: 0.4422
# Epoch 13/30   loss: 0.4665   accuracy: 0.8512   val_loss: 2.1271   val_accuracy: 0.4398
# Epoch 14/30   loss: 0.4017   accuracy: 0.8743   val_loss: 2.2624   val_accuracy: 0.4446
# Epoch 15/30   loss: 0.3452   accuracy: 0.8955   val_loss: 2.3752   val_accuracy: 0.4422
# Epoch 16/30   loss: 0.2925   accuracy: 0.9158   val_loss: 2.5346   val_accuracy: 0.4446
# Epoch 17/30   loss: 0.2504   accuracy: 0.9312   val_loss: 2.6767   val_accuracy: 0.4358
# Epoch 18/30   loss: 0.2141   accuracy: 0.9459   val_loss: 2.7877   val_accuracy: 0.4382
# Epoch 19/30   loss: 0.1797   accuracy: 0.9573   val_loss: 2.9302   val_accuracy: 0.4350
# Epoch 20/30   loss: 0.1498   accuracy: 0.9667   val_loss: 3.0976   val_accuracy: 0.4390
# Epoch 21/30   loss: 0.1273   accuracy: 0.9725   val_loss: 3.1901   val_accuracy: 0.4414
# Epoch 22/30   loss: 0.1092   accuracy: 0.9773   val_loss: 3.3290   val_accuracy: 0.4382
# Epoch 23/30   loss: 0.0915   accuracy: 0.9836   val_loss: 3.4474   val_accuracy: 0.4390
# Epoch 24/30   loss: 0.0788   accuracy: 0.9864   val_loss: 3.5572   val_accuracy: 0.4398
# Epoch 25/30   loss: 0.0704   accuracy: 0.9888   val_loss: 3.6254   val_accuracy: 0.4430
# Epoch 26/30   loss: 0.0627   accuracy: 0.9908   val_loss: 3.7010   val_accuracy: 0.4406
# Epoch 27/30   loss: 0.0540   accuracy: 0.9918   val_loss: 3.7683   val_accuracy: 0.4454
# Epoch 28/30   loss: 0.0488   accuracy: 0.9934   val_loss: 3.8093   val_accuracy: 0.4406
# Epoch 29/30   loss: 0.0471   accuracy: 0.9942   val_loss: 3.8311   val_accuracy: 0.4462
# Epoch 30/30   loss: 0.0444   accuracy: 0.9950   val_loss: 3.8406   val_accuracy: 0.4462
# Average accuracy: 0.4573

# %% [markdown]
# ###### **Testing**

# %%
models = []


def test(loader):
    for fold in range(skf.n_splits):
        model = SentimentClassifier(
            vocab_size=5000,
            embedding_dim=64,
            max_length=120,
            gru_dim=45,
            dense_dim=30,
            num_classes=7,
        ).to(device)
        model.load_state_dict(torch.load(f"gru_fold_{fold + 1}.pth"))
        model.eval()
        models.append(model)

    predicts = []
    true_labels = []

    with torch.no_grad():
        for data in loader:
            inputs = data["inputs"].to(device)
            targets = data["targets"].to(device)

            total_outs = []
            for model in models:
                outputs = model(inputs)
                total_outs.append(outputs)

            total_outs = torch.stack(total_outs)
            _, pred = torch.max(total_outs.mean(0), 1)
            predicts.extend(pred)
            true_labels.extend(targets)

    predicts = torch.stack(predicts).cpu()
    true_labels = torch.stack(true_labels).cpu()
    print(classification_report(true_labels, predicts, digits=4))

# %%
test_dataset = SentimentDataset(test_df, tokenizer, max_length=120)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, num_workers=2)
test(test_loader)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6049    0.6425    0.6231       193
#            1     0.4897    0.5379    0.5126       132
#            2     0.5664    0.5517    0.5590       116
#            3     0.6429    0.2250    0.3333        40
#            4     0.3889    0.1892    0.2545        37
#            5     0.7308    0.4130    0.5278        46
#            6     0.3605    0.4806    0.4120       129
#
#     accuracy                         0.5137       693
#    macro avg     0.5406    0.4343    0.4603       693
# weighted avg     0.5300    0.5137    0.5093       693

# %% [markdown]
# ###### **Inference**

# %%
emotions = ["Enjoyment", "Disgust", "Sadness", "Anger", "Surprise", "Fear", "Other"]


def infer(sentence, max_length=120):
    sentence = " ".join(simple_preprocess(sentence))

    sequence = tokenizer.texts_to_sequences([sentence])
    padded = pad_sequences(
        sequence, maxlen=max_length, padding="post", truncating="post"
    )

    inputs = torch.tensor(padded).to(device)

    total_outs = []
    for model in models:
        outputs = model(inputs)
        total_outs.append(outputs)

    total_outs = torch.stack(total_outs)
    _, pred = torch.max(total_outs.mean(0), 1)

    print(emotions[pred])

# %%
infer("Uồi lại được học bổng thích thế!")
infer("Mấy điều ông ấy nói làm tao ghê tởm.")
infer("Mình lại tạch môn rồi buồn ghê :(")
infer("Đừng có mà động vào người tao. Tao đang hơi bực.")
infer("Không thể tin được, sao có thể được 5 điểm tất cả các môn.")
infer("Lúc thầy ấy giận cả lớp trông thật đáng sợ.")
# Out:
# Enjoyment
# Disgust
# Sadness
# Disgust
# Disgust
# Disgust
